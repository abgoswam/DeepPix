# %% [markdown]
# # Example Sentence : "a pink bicycle"

# %% [markdown]
# ## Original Image (before pre-processing)

# %%
import numpy as np
from scipy.misc import imread, imresize, imsave
import matplotlib.pyplot as plt

img = imread('img_orig.jpg')
print(img.dtype, img.shape)
# Out:
# uint8 (298, 425, 3)

# %%
plt.imshow(img)
plt.show()

# %%
# Resize.
img_32_32 = imresize(img, (32, 32))

print(img_32_32.dtype, img_32_32.shape) 
imsave('img_32_32.jpg', img_32_32)
# Out:
# uint8 (32, 32, 3)

# %% [markdown]
# ## Progressively getting better quality images

# %% [raw]
# [Run on local machine]
#
# convert img_32_32.jpg  -channel RGBA  -blur 5x8  img_32_32_5_8.jpg
# convert img_32_32.jpg  -channel RGBA  -blur 4x8  img_32_32_4_8.jpg
# convert img_32_32.jpg  -channel RGBA  -blur 3x8  img_32_32_3_8.jpg
# convert img_32_32.jpg  -channel RGBA  -blur 2x8  img_32_32_2_8.jpg
# convert img_32_32.jpg  -channel RGBA  -blur 1x8  img_32_32_1_8.jpg

# %%
img = imread('img_32_32_5_8.jpg')
plt.imshow(img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-1ee47faddc55> in <module>()
# ----> 1 img = imread('img_32_32_5_8.jpg')
#       2 plt.imshow(img)
#       3 plt.show()
#
# C:\Users\agoswami\AppData\Local\Continuum\Anaconda3\lib\site-packages\scipy\misc\pilutil.py in imread(name, flatten, mode)
#     154     """
#     155
# --> 156     im = Image.open(name)
#     157     return fromimage(im, flatten=flatten, mode=mode)
#     158
#
# C:\Users\agoswami\AppData\Local\Continuum\Anaconda3\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2408
#    2409     if filename:
# -> 2410         fp = builtins.open(filename, "rb")
#    2411         exclusive_fp = True
#    2412
#
# FileNotFoundError: [Errno 2] No such file or directory: 'img_32_32_5_8.jpg'

# %%
img = imread('img_32_32_4_8.jpg')
plt.imshow(img)
plt.show()

# %%
img = imread('img_32_32_3_8.jpg')
plt.imshow(img)
plt.show()

# %%
img = imread('img_32_32_2_8.jpg')
plt.imshow(img)
plt.show()

# %%
img = imread('img_32_32_1_8.jpg')
plt.imshow(img)
plt.show()

# %%
img = imread('img_32_32.jpg')
plt.imshow(img_32_32)
plt.show()
